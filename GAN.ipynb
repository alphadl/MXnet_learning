# %%
from __future__ import print_function
import os
import matplotlib as mpl
import tarfile
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

# %%
import mxnet as mx
from mxnet import gluon
from mxnet import ndarray as nd
from mxnet.gluon import nn, utils
from mxnet import autograd
import numpy as np

# %%
epochs = 2 # 先設定小一點的方便debug
batch_size = 64
latent_z_size = 100

# %%
use_gpu = True
ctx = mx.gpu() if use_gpu else mx.cpu()

# %%
lr = 0.0002
beta1 = 0.5

# %%
lfw_url = 'http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz'
data_path = 'lfw_dataset'
if not os.path.exists(data_path):
    os.makedirs(data_path)
    data_file = utils.download(lfw_url)
    with tarfile.open(data_file) as tar:
        tar.extractall(path=data_path)
# Out:
# Downloading lfw-deepfunneled.tgz from http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz...

# %%
target_wd = 64
target_ht = 64
img_list = []

# %%
#缩放到64x64，归一化到[-1,1]
def transform(data, target_wd, target_ht):
    # resize to target_wd * target_ht
    data = mx.image.imresize(data, target_wd, target_ht)
    # transpose from (target_wd, target_ht, 3)
    # to (3, target_wd, target_ht)
    data = nd.transpose(data, (2,0,1))
    # normalize to [-1, 1]
    data = data.astype(np.float32)/127.5 - 1
    # if image is greyscale, repeat 3 times to get RGB image.
    if data.shape[0] == 1:
        data = nd.tile(data, (3, 1, 1))
    return data.reshape((1,) + data.shape)

# %%
#打印出来
for path, _, fnames in os.walk(data_path):
    for fname in fnames:
        if not fname.endswith('.jpg'):
            continue
        img = os.path.join(path, fname)
        img_arr = mx.image.imread(img)
        img_arr = transform(img_arr, target_wd, target_ht)
        img_list.append(img_arr)
train_data = mx.io.NDArrayIter(data=nd.concatenate(img_list), batch_size=batch_size)

# %%
#可视化函数
def visualize(img_arr):
    plt.imshow(((img_arr.asnumpy().transpose(1, 2, 0) + 1.0) * 127.5).astype(np.uint8))
    plt.axis('off')

# %%
for i in range(4):
    plt.subplot(1,4,i+1)
    visualize(img_list[i + 10][0])
plt.show()

# %%
#构建生成器
# 建构生成器
nc = 3
ngf = 64
netG = nn.Sequential()
with netG.name_scope():
    # input is Z, going into a convolution
    netG.add(nn.Conv2DTranspose(ngf * 8, 4, 1, 0, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 4 x 4
    netG.add(nn.Conv2DTranspose(ngf * 4, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 8 x 8
    netG.add(nn.Conv2DTranspose(ngf * 2, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 16 x 16
    netG.add(nn.Conv2DTranspose(ngf, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 32 x 32
    netG.add(nn.Conv2DTranspose(nc, 4, 2, 1, use_bias=False))
    netG.add(nn.Activation('tanh'))
    # state size. (nc) x 64 x 64

# %%
# 建构判断器
ndf = 64
netD = nn.Sequential()
with netD.name_scope():
    # input is (nc) x 64 x 64
    netD.add(nn.Conv2D(ndf, 4, 2, 1, use_bias=False))
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 32 x 32
    netD.add(nn.Conv2D(ndf * 2, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 16 x 16
    netD.add(nn.Conv2D(ndf * 4, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 8 x 8
    netD.add(nn.Conv2D(ndf * 8, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 4 x 4
    netD.add(nn.Conv2D(1, 4, 1, 0, use_bias=False))

# %%
 # 损失函数
loss = gluon.loss.SigmoidBinaryCrossEntropyLoss()

# %%
#初始化判断器与生成器
netG.initialize(mx.init.Normal(0.02))
netD.initialize(mx.init.Normal(0.02))

# %%
#优化判断器与生成器
trainerG = gluon.Trainer(netG.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})
trainerD = gluon.Trainer(netD.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})

# %%
netG_filename='Generator.params'
netD_filename='discriminator.params'
# load weighting
#netG.load_params(netG_filename)
#netD.load_params(netD_filename)

# %%
########训练网络#########
from datetime import datetime
import time
import logging
#cpu
real_label = nd.ones((batch_size,))
fake_label = nd.zeros((batch_size,))

# %%
def facc(label, pred):
    pred = pred.ravel()
    label = label.ravel()
    return ((pred > 0.5) == label).mean()
metric = mx.metric.CustomMetric(facc)

# %%
stamp =  datetime.now().strftime('%Y_%m_%d-%H_%M')
logging.basicConfig(level=logging.DEBUG)

for epoch in range(epochs):
    tic = time.time()
    btic = time.time()
    train_data.reset()
    iter = 0
    for batch in train_data:
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        data = batch.data[0].as_in_context(mx.cpu())
        latent_z = mx.nd.random_normal(0, 1, shape=(batch_size, latent_z_size, 1, 1))

        with autograd.record():
            # train with real image
            output = netD(data).reshape((-1, 1))
            errD_real = loss(output, real_label)
            metric.update([real_label,], [output,])

            # train with fake image
            fake = netG(latent_z)
            output = netD(fake.detach()).reshape((-1, 1))
            errD_fake = loss(output, fake_label)
            errD = errD_real + errD_fake
            errD.backward()
            metric.update([fake_label,], [output,])

        trainerD.step(batch.data[0].shape[0])

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        with autograd.record():
            fake = netG(latent_z)
            output = netD(fake).reshape((-1, 1))
            errG = loss(output, real_label)
            errG.backward()

        trainerG.step(batch.data[0].shape[0])

        # Print log infomation every ten batches
        if iter % 10 == 0:
            name, acc = metric.get()
            logging.info('speed: {} samples/s'.format(batch_size / (time.time() - btic)))
            logging.info('discriminator loss = %f, generator loss = %f, binary training acc = %f at iter %d epoch %d'
                     %(nd.mean(errD).asscalar(),
                       nd.mean(errG).asscalar(), acc, iter, epoch))
        iter = iter + 1
        btic = time.time()

    name, acc = metric.get()
    metric.reset()
    netG.save_params(netG_filename)
    netD.save_params(netD_filename)
#     logging.info('\nbinary training acc at epoch %d: %s=%f' % (epoch, name, acc))
#     logging.info('time: %f' % (time.time() - tic))

#     Visualize one generated image for each epoch
#     fake_img = fake[0]
#     visualize(fake_img)
#     plt.show()
# Out:
# INFO:root:speed: 27.287352559498192 samples/s
# INFO:root:discriminator loss = 1.485855, generator loss = 4.475206, binary training acc = 0.531250 at iter 0 epoch 0
# INFO:root:speed: 11.019306649581061 samples/s
# INFO:root:discriminator loss = 0.291672, generator loss = 9.140109, binary training acc = 0.906960 at iter 10 epoch 0
# INFO:root:speed: 11.676185923485411 samples/s
# INFO:root:discriminator loss = 0.096423, generator loss = 12.759300, binary training acc = 0.942336 at iter 20 epoch 0
# INFO:root:speed: 11.521206370213907 samples/s
# INFO:root:discriminator loss = 0.209317, generator loss = 14.354611, binary training acc = 0.918347 at iter 30 epoch 0
# INFO:root:speed: 11.683343306822524 samples/s
# INFO:root:discriminator loss = 0.082337, generator loss = 15.817233, binary training acc = 0.905107 at iter 40 epoch 0
# INFO:root:speed: 11.633514849689401 samples/s
# INFO:root:discriminator loss = 1.704190, generator loss = 24.599346, binary training acc = 0.899510 at iter 50 epoch 0
# INFO:root:speed: 11.520928474484192 samples/s
# INFO:root:discriminator loss = 1.618816, generator loss = 25.151434, binary training acc = 0.891393 at iter 60 epoch 0
# INFO:root:speed: 11.736471786520266 samples/s
# INFO:root:discriminator loss = 1.210958, generator loss = 23.122177, binary training acc = 0.888974 at iter 70 epoch 0
# INFO:root:speed: 11.560789706088949 samples/s
# INFO:root:discriminator loss = 0.541380, generator loss = 22.327736, binary training acc = 0.879533 at iter 80 epoch 0
# INFO:root:speed: 11.601958604890566 samples/s
# INFO:root:discriminator loss = 0.910881, generator loss = 21.170109, binary training acc = 0.871566 at iter 90 epoch 0
# INFO:root:speed: 11.620720349669948 samples/s
# INFO:root:discriminator loss = 1.121296, generator loss = 12.901503, binary training acc = 0.865099 at iter 100 epoch 0
# INFO:root:speed: 11.695942863018688 samples/s
# INFO:root:discriminator loss = 1.814958, generator loss = 18.463331, binary training acc = 0.860923 at iter 110 epoch 0
# INFO:root:speed: 11.567370104581672 samples/s
# INFO:root:discriminator loss = 2.254090, generator loss = 7.759962, binary training acc = 0.852014 at iter 120 epoch 0
# INFO:root:speed: 11.739745501590473 samples/s
# INFO:root:discriminator loss = 0.569128, generator loss = 5.242808, binary training acc = 0.849535 at iter 130 epoch 0
# INFO:root:speed: 0.03122395470880375 samples/s
# INFO:root:discriminator loss = 1.308578, generator loss = 2.820862, binary training acc = 0.846687 at iter 140 epoch 0
# INFO:root:speed: 3.4013037436692346 samples/s
# INFO:root:discriminator loss = 0.611670, generator loss = 4.724623, binary training acc = 0.844474 at iter 150 epoch 0
# INFO:root:speed: 3.6060797621011016 samples/s
# INFO:root:discriminator loss = 0.488338, generator loss = 5.161783, binary training acc = 0.842294 at iter 160 epoch 0
# INFO:root:speed: 3.5473025620285967 samples/s
# INFO:root:discriminator loss = 0.610767, generator loss = 3.523351, binary training acc = 0.844435 at iter 170 epoch 0
# INFO:root:speed: 3.4690118396959084 samples/s
# INFO:root:discriminator loss = 0.913163, generator loss = 4.621199, binary training acc = 0.844786 at iter 180 epoch 0
# INFO:root:speed: 3.3809679868652385 samples/s
# INFO:root:discriminator loss = 1.530673, generator loss = 11.307821, binary training acc = 0.845263 at iter 190 epoch 0
# INFO:root:speed: 3.466947512594826 samples/s
# INFO:root:discriminator loss = 0.702999, generator loss = 4.119878, binary training acc = 0.846859 at iter 200 epoch 0
# /Users/alphadl/miniconda3/envs/python36/lib/python3.6/site-packages/mxnet/gluon/block.py:345: UserWarning: save_params is deprecated. Please use save_parameters. Note that if you want load from SymbolBlock later, please use export instead. For details, see https://mxnet.incubator.apache.org/tutorials/gluon/save_load_params.html
#   warnings.warn("save_params is deprecated. Please use save_parameters. "
# INFO:root:speed: 11.094847632354403 samples/s
# INFO:root:discriminator loss = 2.864075, generator loss = 10.396252, binary training acc = 0.585938 at iter 0 epoch 1
# INFO:root:speed: 3.4370219910263833 samples/s
# INFO:root:discriminator loss = 0.326882, generator loss = 5.847409, binary training acc = 0.824574 at iter 10 epoch 1
# INFO:root:speed: 3.0526779173087832 samples/s
# INFO:root:discriminator loss = 1.286950, generator loss = 13.269932, binary training acc = 0.852307 at iter 20 epoch 1
# INFO:root:speed: 3.4740402464876126 samples/s
# INFO:root:discriminator loss = 0.578588, generator loss = 4.036146, binary training acc = 0.827369 at iter 30 epoch 1
# INFO:root:speed: 11.208239155571565 samples/s
# INFO:root:discriminator loss = 0.500648, generator loss = 4.877997, binary training acc = 0.844893 at iter 40 epoch 1
# INFO:root:speed: 11.439714679037996 samples/s
# INFO:root:discriminator loss = 1.100048, generator loss = 9.455925, binary training acc = 0.849112 at iter 50 epoch 1
# INFO:root:speed: 11.6070043256324 samples/s
# INFO:root:discriminator loss = 0.426057, generator loss = 4.919839, binary training acc = 0.850282 at iter 60 epoch 1
# INFO:root:speed: 11.49020794615006 samples/s
# INFO:root:discriminator loss = 0.892822, generator loss = 6.079959, binary training acc = 0.854093 at iter 70 epoch 1
# INFO:root:speed: 11.570918725118698 samples/s
# INFO:root:discriminator loss = 0.567977, generator loss = 3.438118, binary training acc = 0.858893 at iter 80 epoch 1
# INFO:root:speed: 11.503390352158663 samples/s
# INFO:root:discriminator loss = 0.845764, generator loss = 7.760269, binary training acc = 0.858087 at iter 90 epoch 1
# INFO:root:speed: 11.437997411536177 samples/s
# INFO:root:discriminator loss = 0.170405, generator loss = 8.096424, binary training acc = 0.856745 at iter 100 epoch 1
# INFO:root:speed: 11.609836124847554 samples/s
# INFO:root:discriminator loss = 0.507418, generator loss = 6.535881, binary training acc = 0.854448 at iter 110 epoch 1
# INFO:root:speed: 11.513306899973344 samples/s
# INFO:root:discriminator loss = 0.330870, generator loss = 5.110021, binary training acc = 0.857825 at iter 120 epoch 1
# INFO:root:speed: 11.47244738960008 samples/s
# INFO:root:discriminator loss = 0.841046, generator loss = 5.705087, binary training acc = 0.860091 at iter 130 epoch 1
# INFO:root:speed: 11.491190216620993 samples/s
# INFO:root:discriminator loss = 0.405326, generator loss = 4.639055, binary training acc = 0.864860 at iter 140 epoch 1
# INFO:root:speed: 11.537645817074845 samples/s
# INFO:root:discriminator loss = 0.243203, generator loss = 4.961875, binary training acc = 0.867239 at iter 150 epoch 1
# INFO:root:speed: 11.415710050345393 samples/s
# INFO:root:discriminator loss = 0.214221, generator loss = 5.041588, binary training acc = 0.871700 at iter 160 epoch 1
# INFO:root:speed: 11.480919854346729 samples/s
# INFO:root:discriminator loss = 1.008836, generator loss = 3.737634, binary training acc = 0.873447 at iter 170 epoch 1
# INFO:root:speed: 11.096754681713819 samples/s
# INFO:root:discriminator loss = 0.593761, generator loss = 2.538013, binary training acc = 0.870813 at iter 180 epoch 1
# INFO:root:speed: 10.883385333421016 samples/s
# INFO:root:discriminator loss = 0.275872, generator loss = 3.680709, binary training acc = 0.870869 at iter 190 epoch 1
# INFO:root:speed: 10.902231193759288 samples/s
# INFO:root:discriminator loss = 0.501604, generator loss = 5.835136, binary training acc = 0.870452 at iter 200 epoch 1

# %%
num_image = 8
for i in range(num_image):
    latent_z = mx.nd.random_normal(0, 1, shape=(1, latent_z_size, 1, 1))
    img = netG(latent_z)
    plt.subplot(2,4,i+1)
    visualize(img[0])
plt.show()
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
